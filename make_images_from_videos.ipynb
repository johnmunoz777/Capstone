# %% [markdown]
# ### Total Frames in a 1-Minute Video with 60 FPS
#
# If your video is **1 minute** long and has **60 frames per second (FPS)**, you can calculate the total number of frames in the video using the following formula:
#
# - **Video Duration** = 1 minute = 60 seconds
# - **Frames per second (FPS)** = 60
#
# #### Formula:
# $$
# \text{Total frames} = \text{FPS} \times \text{Video Duration (in seconds)}
# $$
# $$
# \text{Total frames} = 60 \times 60 = 3600
# $$
#
# So, the total number of frames in the video is **3600 frames**.
#
# ---
#
# ### Selecting Every 5th Frame
#
# If you want to select every 5th frame from the video, you can calculate the total number of images you will export by dividing the total number of frames by 5.
#
# #### Formula:
# $$
# \text{Number of images} = \frac{\text{Total frames}}{5}
# $$
# $$
# \text{Number of images} = \frac{3600}{5} = 720
# $$
#
# Thus, if you take every 5th frame, you will get **720 images**.
#
# ---
#
# ### How to Extract 20 Images from the Video
#
# If you want to extract exactly **20 images** from the video, you need to calculate how many frames you need to skip between each image.
#
# #### Formula to Calculate the Interval:
# $$
# x = \frac{\text{Total frames}}{\text{Desired number of images}} = \frac{3600}{20} = 180
# $$
#
# So, to get **20 images**, you will need to extract every **180th frame** from the video.

# %% [markdown]
# ### Goal of this project is for every person we want 100 images
# *   For a 1 minute video and we want 100 images we need every `36th` frame.
# ```python
# # Python code
# frames_needed = 3600 / 100  |36

# %%
import cv2
import numpy as np
from IPython.display import Video
import random
import matplotlib.pyplot as plt
import os

# %%
video_path = 'john.mp4'
cap = cv2.VideoCapture(video_path)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
random_frame_number = random.randint(0, total_frames - 1)
# Set the video capture to the random frame
cap.set(cv2.CAP_PROP_POS_FRAMES, random_frame_number)
ret, frame = cap.read()
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(frame_rgb)
plt.axis('off')  # Hide the axis for cleaner view
plt.show()
cap.release()
### Write out that random frame 
write_out_frame_example=False
if write_out_frame_example:
    video_path = 'john.mp4'
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    random_frame_number = random.randint(0, total_frames - 1)
    cap.set(cv2.CAP_PROP_POS_FRAMES, random_frame_number)
    ret, frame = cap.read()
    cv2.imwrite('john_test.jpg', frame)
    cap.release()
    # Now, read the saved image using OpenCV
    image = cv2.imread('john_test.jpg')
    print(f"Image shape: {image.shape}")
# Convert the image from BGR (OpenCV format) to RGB (Matplotlib format)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# Display the image using Matplotlib
    plt.imshow(image_rgb)
#plt.axis('off')  # Hide axis for a cleaner view
    plt.show()

# %%
image = cv2.imread('john_test.jpg')
print(f"Original image shape: {image.shape}")
# Resize the image to 416x416 (YOLO standard input size)
resized_image = cv2.resize(image, (416, 416))
# Print the shape of the resized image
print(f"Resized image shape: {resized_image.shape}")
# Convert the resized image from BGR (OpenCV format) to RGB (Matplotlib format)
image_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)
# Display the resized image using Matplotlib
plt.imshow(image_rgb)
plt.axis('off')  # Hide axis for a cleaner view
plt.show()
# Out:
# Original image shape: (1920, 1080, 3)
# Resized image shape: (416, 416, 3)

# %%
video_path = 'john.mp4'
Video(video_path, width=600, height=400)
# Out:
# <video src="john.mp4" controls  width="600"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# Path to the video file
video_path = 'john.mp4'  # Replace with your actual video file path
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print("Error: Could not open the video.")
else:
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Frames per second (FPS): {fps}")
cap.release()
# Out:
# Frames per second (FPS): 60.00100137725654

# %%
video_path = 'john.mp4'  
cap = cv2.VideoCapture(video_path)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = cap.get(cv2.CAP_PROP_FPS)
print(f"Total number of frames: {total_frames}")
print(f"Frames per second (FPS): {fps}")
duration_seconds = total_frames / fps
print(f"Video duration in seconds: {int(duration_seconds)} seconds")
duration_minutes = duration_seconds // 60
duration_hours = duration_minutes // 60
print(f"Video duration in minutes: {int(duration_minutes)} minutes")
print(f"Video duration in hours: {int(duration_hours)} hours")
cap.release()
# Out:
# Total number of frames: 3675
# Frames per second (FPS): 60.00100137725654
# Video duration in seconds: 61 seconds
# Video duration in minutes: 1 minutes
# Video duration in hours: 0 hours

# %%
3675/100
# Out:
# 36.75

# %%
## if u want the exact calculation use this 
video_path = 'john.mp4'  # Replace with your actual video file path
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print("Error: Could not open the video.")
else:
    # Get total frames in the video
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Get frames per second (FPS)
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Frames per second (FPS): {fps}")

    # Calculate the duration of the video in seconds
    duration_seconds = total_frames / fps
    print(f"Calculated video duration in seconds: {duration_seconds:.2f} seconds")
    
    # Round duration for better accuracy in minutes and hours
    duration_seconds_rounded = round(duration_seconds)
    print(f"Rounded video duration in seconds: {duration_seconds_rounded} seconds")

    # Convert to minutes and hours
    duration_minutes = duration_seconds_rounded // 60
    duration_hours = duration_minutes // 60

    print(f"Video duration in minutes: {duration_minutes} minutes")
    print(f"Video duration in hours: {duration_hours} hours")

cap.release()
# Out:
# Frames per second (FPS): 60.00100137725654
# Calculated video duration in seconds: 61.25 seconds
# Rounded video duration in seconds: 61 seconds
# Video duration in minutes: 1 minutes
# Video duration in hours: 0 hours

# %%
### issues with moviepy package returns the same results as above 
#from moviepy.editor import VideoFileClip


# Load video
#video_path = "your_video_file.mp4"
#clip = VideoFileClip(video_path)

# Get video duration in seconds (whole number)
#duration_seconds = int(clip.duration)

# Convert to minutes and hours
#duration_minutes = duration_seconds // 60
#duration_hours = duration_minutes // 60

# Print durations
#print(f"Duration in seconds: {duration_seconds} seconds")
#print(f"Duration in minutes: {duration_minutes} minutes")
#print(f"Duration in hours: {duration_hours} hours")

# %%
video_path='john.mp4'
cap = cv2.VideoCapture(video_path)
total_images=100
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
frame_interval = total_frames // total_images
frame_interval 

for i in range(total_images):
    print(i * frame_interval)
    my_new_frame_number=i*frame_interval
    if my_new_frame_number > 396:
        break
    cap.set(cv2.CAP_PROP_POS_FRAMES, i * frame_interval)
    ret, frame = cap.read()
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    plt.imshow(frame_rgb)
    plt.axis('off')  # Hide the axis for cleaner view
    plt.show()
cap.release()
# Out:
# 0
# 36
# 72
# 108
# 144
# 180
# 216
# 252
# 288
# 324
# 360
# 396
# 432

# %%
video_path='john.mp4'
cap = cv2.VideoCapture(video_path)
total_images=100
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
frame_interval = total_frames // total_images
frame_interval 
for i in range(total_images):
    frame_number = i * frame_interval
    if frame_number >  100:
        break
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
    ret, frame = cap.read()
    frame_with_title = frame.copy()
    cv2.putText(frame_with_title, f"Frame {frame_number}", 
                (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 
                1, (255, 0, 0), 2, cv2.LINE_AA)
    
    frame_rgb = cv2.cvtColor(frame_with_title, cv2.COLOR_BGR2RGB)
    plt.imshow(frame_rgb)
    plt.axis('off')  # Hide the axis for cleaner view
    plt.show()

# %%
### Only used if you want to resize the images to 416x416
### will be moved to the output folder john 
### total_images  this is how many images you want to extract from the video
### remember this is resizing the images so only use if we want to resize the images
### dont use this we are not resizing the images anymore

def export_frames(video_path, total_images, output_folder='john'):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the interval to capture frames (frame_interval)
    frame_interval = total_frames // total_images

    # Loop through the video to capture the required frames
    for i in range(total_images):
        # Set the video capture to the desired frame (every frame_interval-th frame)
        cap.set(cv2.CAP_PROP_POS_FRAMES, i * frame_interval)

        # Read the frame
        ret, frame = cap.read()

        # Check if the frame was successfully read
        if ret:
            # Resize the frame to (416, 416)
            resized_frame = cv2.resize(frame, (416, 416))

            # Define the filename for the frame (e.g., john_1.jpg, john_2.jpg, ...)
            filename = os.path.join(output_folder, f'john_{i + 1}.jpg')

            # Save the frame as a .jpg image
            cv2.imwrite(filename, resized_frame)

    # Release the video capture object
    cap.release()

    print(f"Exported {total_images} frames to {output_folder}.")

# Example usage:
video_path = 'john.mp4'  # Replace with your video file path
total_images = 20  # You can change this value to get more or fewer images

# Call the function
export_frames(video_path, total_images)

# %%
class VideoDescriptionsJM:
    def __init__(self, video_path):
        self.video_path = video_path
        self.cap = cv2.VideoCapture(video_path)
        if not self.cap.isOpened():
            print("Error: Could not open the video.")
        
        self.total_frames = int(self.cap.get(cv2.CAP_PROP_FRAME_COUNT))
        self.fps = self.cap.get(cv2.CAP_PROP_FPS)

    def play_video_full(self):
        """Function to play the video"""
        video = cv2.VideoCapture(self.video_path)
        while video.isOpened():
            ret, frame = video.read()
            if not ret:
                break
            cv2.imshow('Video', frame)
            if cv2.waitKey(int(1000/self.fps)) & 0xFF == ord('q'):
                break
        video.release()
        cv2.destroyAllWindows()
        
    def play_video(self):
        """Function to play the video inline in Jupyter using IPython's Video."""
        video = Video(self.video_path, width=600, height=400)
        display(video)

    def show_random_frame(self):
        """Function to take a random frame and show that image"""
        random_frame_number = random.randint(0, self.total_frames - 1)
        self.cap.set(cv2.CAP_PROP_POS_FRAMES, random_frame_number)
        ret, frame = self.cap.read()
        if ret:
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            plt.imshow(frame_rgb)
            plt.axis('off')
            plt.show()

    def save_random_frame(self):
        """Function to save the random frame as an image"""
        random_frame_number = random.randint(0, self.total_frames - 1)
        self.cap.set(cv2.CAP_PROP_POS_FRAMES, random_frame_number)
        ret, frame = self.cap.read()
        if ret:
            cv2.imwrite('random_frame.jpg', frame)
            print("Random frame saved as 'random_frame.jpg'")

    def show_saved_frame(self):
        """Function to read and show the saved random frame"""
        image = cv2.imread('random_frame.jpg')
        if image is not None:
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            plt.imshow(image_rgb)
            plt.axis('off')
            plt.show()
        else:
            print("Error: Image not found.")

    def resize_and_show(self, image, width=416, height=416):
        """Function to resize any image and show side by side with the original"""
        resized_image = cv2.resize(image, (width, height))
        print(f"Original shape: {image.shape}, Resized shape: {resized_image.shape}")
        
        # Display side by side
        fig, axes = plt.subplots(1, 2, figsize=(12, 6))
        axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        axes[0].set_title("Original")
        axes[0].axis('off')
        
        axes[1].imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
        axes[1].set_title("Resized")
        axes[1].axis('off')
        
        plt.show()

    def video_description(self):
        """Function to show video details like FPS, duration, etc."""
        duration_seconds = self.total_frames / self.fps
        duration_minutes = duration_seconds // 60
        duration_hours = duration_minutes // 60

        print(f"Total number of frames: {self.total_frames}")
        print(f"Frames per second (FPS): {self.fps}")
        print(f"Video duration in seconds: {int(duration_seconds)} seconds")
        print(f"Video duration in minutes: {int(duration_minutes)} minutes")
        print(f"Video duration in hours: {int(duration_hours)} hours")

    def calculate_frame_interval(self, num_images=100):
        """Function to calculate the frame interval for extracting 'num_images' frames"""
        frames_needed = self.total_frames // num_images
        print(f"To extract {num_images} images from {self.total_frames} total frames, use every {frames_needed}th frame.")
        
    def export_frames(self, total_images=100, output_folder='john'):
        """Function to export 'total_images' frames from the video and save them in a folder without resizing."""
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        # Calculate the interval to capture frames (frame_interval)
        frame_interval = self.total_frames // total_images

        # Loop through the video to capture the required frames
        for i in range(total_images):
            # Set the video capture to the desired frame (every frame_interval-th frame)
            self.cap.set(cv2.CAP_PROP_POS_FRAMES, i * frame_interval)

            # Read the frame
            ret, frame = self.cap.read()

            # Check if the frame was successfully read
            if ret:
                # Define the filename for the frame (e.g., john_1.jpg, john_2.jpg, ...)
                filename = os.path.join(output_folder, f'{output_folder}_{i + 1}.jpg')

                # Save the frame as a .jpg image without resizing
                cv2.imwrite(filename, frame)

        print(f"Exported {total_images} frames to {output_folder}.")

        # Release the video capture object
        self.cap.release()
        
        
    def export_frames_resize(self, total_images=100, output_folder='john'):
        """Function to export 'total_images' frames from the video and save them in a folder"""
        # Create the output folder if it doesn't exist
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        # Calculate the interval to capture frames (frame_interval)
        frame_interval = self.total_frames // total_images

        # Loop through the video to capture the required frames
        for i in range(total_images):
            # Set the video capture to the desired frame (every frame_interval-th frame)
            self.cap.set(cv2.CAP_PROP_POS_FRAMES, i * frame_interval)

            # Read the frame
            ret, frame = self.cap.read()

            # Check if the frame was successfully read
            if ret:
                # Resize the frame to (416, 416)
                resized_frame = cv2.resize(frame, (416, 416))

                # Define the filename for the frame (e.g., john_1.jpg, john_2.jpg, ...)
                filename = os.path.join(output_folder, f'{output_folder}_{i + 1}.jpg')

                # Save the frame as a .jpg image
                cv2.imwrite(filename, resized_frame)

        print(f"Exported {total_images} frames to {output_folder}.")

        # Release the video capture object
        self.cap.release()

# %%
video_path = 'john.mp4'
video_obj = VideoDescriptionsJM(video_path)
video_obj.calculate_frame_interval()
# Out:
# To extract 100 images from 3675 total frames, use every 36th frame.

# %%
video_obj.play_video()

# %%
video_path = 'videos_project/mike.mp4'
video_obj = VideoDescriptionsJM(video_path)
video_obj.calculate_frame_interval()
# Out:
# To extract 100 images from 846 total frames, use every 8th frame.

# %%
os.listdir('./videos_project')
# Out:
# ['classmate.mp4',
#  'john.mp4',
#  'mike.mp4',
#  'ron.mp4',
#  'shanti.mp4',
#  'tom.mp4',
#  'will.mp4']

# %%
for x in os.listdir('./videos_project'):
    print("name of video is ")
    print(x)
    my_dirs='./videos_project'
    video_path = f'{my_dirs}/{x}'
    video_obj = VideoDescriptionsJM(video_path)
    video_obj.calculate_frame_interval()
    print("*"*500)
    video_obj.video_description()
    print("*"*500)
    video_obj.play_video()
    print("*"*500)
    print("*"*500)
    print("Show A Random Frame")
    video_obj.show_random_frame()
# Out:
# name of video is
# classmate.mp4
# To extract 100 images from 1818 total frames, use every 18th frame.
# ********************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# Total number of frames: 1818
# Frames per second (FPS): 30.012788727723365
# Video duration in seconds: 60 seconds
# Video duration in minutes: 1 minutes
# Video duration in hours: 0 hours
# ...

# %%
a='will.mp4'
a=a.split('.')[0]
print(a)
# Out:
# will

# %%
for x in os.listdir('./videos_project'):
    print("name of video is ")
    print(x)
    my_dirs='./videos_project'
    video_path = f'{my_dirs}/{x}'
    video_obj = VideoDescriptionsJM(video_path)
    video_obj.calculate_frame_interval(num_images=140)
    a=x
    a=a.split('.')[0]
    video_obj.export_frames(total_images=140, output_folder=a)
# Out:
# name of video is
# classmate.mp4
# To extract 140 images from 1818 total frames, use every 12th frame.
# Exported 140 frames to classmate.
# name of video is
# john.mp4
# To extract 140 images from 3675 total frames, use every 26th frame.
# Exported 140 frames to john.
# name of video is
# mike.mp4
# To extract 140 images from 846 total frames, use every 6th frame.
# Exported 140 frames to mike.
# name of video is
# ron.mp4
# To extract 140 images from 589 total frames, use every 4th frame.
# Exported 140 frames to ron.
# name of video is
# shanti.mp4
# To extract 140 images from 1875 total frames, use every 13th frame.
# Exported 140 frames to shanti.
# name of video is
# tom.mp4
# To extract 140 images from 1787 total frames, use every 12th frame.
# Exported 140 frames to tom.
# name of video is
# will.mp4
# To extract 140 images from 1696 total frames, use every 12th frame.
# Exported 140 frames to will.

# %%
import cv2
import torch
import numpy as np
from deepface import DeepFace  # For emotion detection
from facenet_pytorch import MTCNN  # For face detection

# Initialize Face Detector
face_detector = MTCNN(keep_all=True)

# Load video
video_path = "john.mp4"
cap = cv2.VideoCapture(video_path)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # Exit when the video ends
    
    # Convert frame to RGB (required for MTCNN)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces
    boxes, _ = face_detector.detect(frame_rgb)

    if boxes is not None:
        for box in boxes:
            x1, y1, x2, y2 = map(int, box)
            
            # Extract the face region
            face = frame_rgb[y1:y2, x1:x2]
            if face.size == 0:
                continue  # Skip if face is empty
            
            # Resize face for emotion model
            face = cv2.resize(face, (48, 48))
            face_gray = cv2.cvtColor(face, cv2.COLOR_RGB2GRAY)

            # Predict emotion using DeepFace
            try:
                prediction = DeepFace.analyze(face_gray, actions=['emotion'], enforce_detection=False)
                emotion = prediction[0]['dominant_emotion']
            except:
                emotion = "Unknown"

            # Draw bounding box around face
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Display emotion label
            cv2.putText(frame, emotion, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    
    # Show video with emotions labeled
    cv2.imshow("Real-Time Emotion Detection", frame)

    # Exit when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release everything
cap.release()
cv2.destroyAllWindows()
